# %% [markdown]
# # Sistemas Lineales

# %%
from sympy import * 
import IPython
from ubogsla18p import *
from sympy.plotting import plot
#import numpy as np
import matplotlib.pyplot as plt
t = symbols('t')
intervalo=(t,0,.005)

# %% [markdown]
# <img src="audifono.PNG"/>
#
# <img src="circuito1.PNG"/>
#
# La relación entre la corriente de entrada y el voltaje de salida es
# '
# $$v_1=L \frac{di_1}{dt}$$
#
# Si la entrada es:

# %%
i1=sin(2*pi*500*t)
i1
# Out:
# sin(1000*pi*t)

# %%
plot(i1,intervalo)

# %%
sonar(i1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Entonces la salida es:
# $v_1=L \frac{di_1}{dt}$

# %%
L=Rational(1,2000)
L
# Out:
# 1/2000

# %%
v1=L*diff(i1,t)
v1
# Out:
# pi*cos(1000*pi*t)/2

# %%
plot(i1,v1,intervalo)

# %%
sonar(v1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <img src="circuito2.PNG"/>
#
# $$v_2=L \frac{di_2}{dt}$$
#
# En el segundo circuito la frecuencia es mayor.
# Si la entrada es

# %%
i2=sin(2*pi*900*t)
i2
# Out:
# sin(1800*pi*t)

# %%
plot(i2,intervalo)

# %%
sonar(i2)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Entonces la salida es:
# $v_2=L \frac{di_2}{dt}$

# %%
v2=L*diff(i2,t)
v2
# Out:
# 9*pi*cos(1800*pi*t)/10

# %%
plot(i2,v2,intervalo)

# %%
sonar(v2)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <img src="circuito12.PNG"/>
#
# Si la entrada es: $i_{12}=i_1 + i_2$

# %%
i12=i1+i2
i12
# Out:
# sin(1000*pi*t) + sin(1800*pi*t)

# %%
plot(i12,intervalo)

# %%
sonar(i12)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Entonces la salida es:
# $v_{12}=L \frac{di_{12}}{dt}=L \frac{d(i_{1}+i_{2})}{dt}=L \frac{di_{1}}{dt}+L \frac{di_{2}}{dt}=v_1+v_2$

# %%
v12=v1+v2
v12
# Out:
# pi*cos(1000*pi*t)/2 + 9*pi*cos(1800*pi*t)/10

# %%
plot(i12,v12,intervalo)

# %%
sonar(v12)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# En este sencillo ejercicio se ilustra una propiedad muy interesante de la derivada.
# $$v_{12}=L \frac{di_{12}}{dt}=L \frac{d(i_{1}+i_{2})}{dt}=L \frac{di_{1}}{dt}+L \frac{di_{2}}{dt}=v_1+v_2$$
# Esta propiedad se llama linealidad y es muy útil, porque para entender la transformación de señales 'complejas' basta con entender la transformación de señales 'sencillas'.
